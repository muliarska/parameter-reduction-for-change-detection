# %% [markdown]
# # SNUNet-CD Experiments with the Fractional Filter Method Applied

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install opencv-python tqdm tensorboardX sklearn
! pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 14.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sklearn: filename=sklearn-0.0.post4-py3-none-any.whl size=2951 sha256=b0f4998b4de8b6ab383802eefd098f8501607a76335dc6dd8790d733781513e5
#   Stored in directory: /root/.cache/pip/wheels/46/b8/69/4f7789b7d2fc0718a44cbc4ae5d40970a40c22c472ae50f0a1
# Successfully built sklearn
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
! cd /content/drive/MyDrive/Thesis/Siam-NestedUNet && python train.py
# Out:
# INFO:root:GPU AVAILABLE? True
# INFO:root:STARTING Dataset Creation
# 5000
# 1499
# INFO:root:STARTING Dataloading
# INFO:root:LOADING Model
# Approach fractional is used.
# 0 block
# 1 block
# 2 block
# 3 block
# 4 block
# end
# +----------------------+------------+
# |       Modules        | Parameters |
# +----------------------+------------+
# | conv0_0.conv1.weight |    864     |
# |  conv0_0.conv1.bias  |     32     |
# |  conv0_0.bn1.weight  |     32     |
# |   conv0_0.bn1.bias   |     32     |
# |   conv0_0.conv2.A    |    1024    |
# | conv0_0.conv2.sigma  |    1024    |
# |   conv0_0.conv2.x0   |    1024    |
# |   conv0_0.conv2.y0   |    1024    |
# |   conv0_0.conv2.a    |    1024    |
# |   conv0_0.conv2.b    |    1024    |
# |  conv0_0.bn2.weight  |     32     |
# |   conv0_0.bn2.bias   |     32     |
# | conv1_0.conv1.weight |   18432    |
# |  conv1_0.conv1.bias  |     64     |
# |  conv1_0.bn1.weight  |     64     |
# |   conv1_0.bn1.bias   |     64     |
# ...

# %%
! cd /content/drive/MyDrive/Thesis/Siam-NestedUNet && python train.py
# Out:
# Streaming output truncated to the last 5000 lines.
#   logpt = F.log_softmax(input)
# /content/drive/MyDrive/Thesis/Siam-NestedUNet/utils/metrics.py:33: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   logpt = F.log_softmax(input)
# /content/drive/MyDrive/Thesis/Siam-NestedUNet/utils/metrics.py:33: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   logpt = F.log_softmax(input)
# /content/drive/MyDrive/Thesis/Siam-NestedUNet/utils/metrics.py:33: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   logpt = F.log_softmax(input)
# /content/drive/MyDrive/Thesis/Siam-NestedUNet/utils/metrics.py:33: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   logpt = F.log_softmax(input)
# ...

# %%
! cd /content/drive/MyDrive/Thesis/Siam-NestedUNet && python eval.py
# Out:
# INFO:root:STARTING Dataset Creation
# INFO:root:STARTING Dataloading
# Using method: fractional
# 100% 188/188 [18:20<00:00,  5.85s/it]
# Evaluation time: 1100.35 seconds
# Precision: 0.8912449086284516
# Recall: 0.6020343601381393
# F1-Score: 0.7186332382899665
